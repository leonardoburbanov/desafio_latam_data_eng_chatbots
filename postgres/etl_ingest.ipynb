# %%
import pandas as pd

startups = pd.read_csv("./startups.csv")
startups
# Out:
#             name                             location  \
# 0         Reddit               San Francisco, CA, USA
# 1           Kiko                   Cambridge, MA, USA
# 2     Clickfacts               San Francisco, CA, USA
# 3      TextPayMe                     Redmond, WA, USA
# 4          Loopt               Mountain View, CA, USA
# ...          ...                                  ...
# 4337        Leya  Stockholm, Stockholm County, Sweden
# 4338  Upsolve AI      London, England, United Kingdom
# 4339    AgentHub                Vancouver, BC, Canada
# 4340     Lantern                                  NaN
# 4341   GovernGPT                  Toronto, ON, Canada
#
#                                             description batch  \
# 0                        The frontpage of the internet.   S05
# 1     We're the best online calendar solution to eve...   S05
# 2                                                   NaN   S05
# 3                                                   NaN   S05
# 4                                                   NaN   S05
# ...                                                 ...   ...
# 4337                 An honest AI assistant for lawyers   W24
# 4338       Your AI Copilot for DataOps & Data Analytics   W24
# 4339  A no-code platform for automating workflows wi...   W24
# 4340  PostgreSQL vector database extension to build ...   W24
# 4341                             Compliance 'Grammarly'   W24
#
#                              industry  \
# 0             ["Consumer", "Content"]
# 1             ["B2B", "Productivity"]
# 2                 ["B2B", "Security"]
# 3     ["Fintech", "Consumer Finance"]
# 4              ["Consumer", "Social"]
# ...                               ...
# 4337                 ["B2B", "Legal"]
# 4338             ["B2B", "Analytics"]
# 4339                          ["B2B"]
# 4340                          ["B2B"]
# 4341                      ["Fintech"]
#
#                                    extended_description
# 0     Founded by Steve Huffman and Alexis Ohanian in...
# 1     Kiko is a web calendar for anyone who wants to...
# 2     ClickFacts is a Malware Software Solutions com...
# 3     Founded in 2005, TextPayMe is an SMS payment s...
# 4     Loopt, based in Silicon-Valley and backed by l...
# ...                                                 ...
# 4337  Leya is an AI assistant designed for legal pro...
# 4338  Upsolve’s AI contextualize your data and make ...
# 4339  AgentHub is a platform for automating repetiti...
# 4340                                                NaN
# 4341  GovernGPT reviews Marketing Materials in Real-...
#
# [4342 rows x 6 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg://testuser:testpwd@localhost:5432/vectordb')

# %%
startups.to_sql('startups_yc', engine, if_exists='replace', index=False)
# Out:
# -1
